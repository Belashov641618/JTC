# %% [markdown]
# <a href="https://colab.research.google.com/github/Belashov641618/JTC/blob/master/colab/TestConvolutionslCompression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Belashov641618/JTC.git
# Out:
# Cloning into 'JTC'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 43 (delta 21), reused 31 (delta 11), pack-reused 0
# Receiving objects: 100% (43/43), 15.08 KiB | 15.08 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
! pip install belashovplot
! pip install matplotlib
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for belashovplot: filename=belashovplot-1.0-py3-none-any.whl size=12758 sha256=76cd7918a90e76926011610f0873552dc3a372a063869588c3c3b75285295311
#   Stored in directory: /root/.cache/pip/wheels/55/7b/e2/e5bf08c4c48d0989afbcb220497fa4bb6805a32f6c7826eece
# Successfully built belashovplot
# ...

# %%
from belashovplot.belashovplot import DefaultFont, DefaultBigHeader, DefaultHeader, DefaultDefault, DefaultCaption, DefaultSmallCaption
DefaultFont['font'] = 'DejaVu Sans'
for Font in [DefaultBigHeader, DefaultHeader, DefaultDefault, DefaultCaption, DefaultSmallCaption]:
  Font.Font = 'DejaVu Sans'

# %%
# %cd JTC
# Out:
# /content/JTC

# %%
! git pull
# Out:
# Already up to date.

# %%
from Flowers import ConvolutionalCompression

compressor = ConvolutionalCompression('Flowers', batch=612, size=511, compression=0.1)
compressor.test()
# Out:
# ...
# 100%|██████████| 344862509/344862509 [00:12<00:00, 26757461.55it/s]
# Extracting data/flowers-102/102flowers.tgz to data/flowers-102
# ...
# 100%|██████████| 14989/14989 [00:00<00:00, 13601995.38it/s]

# %%
import torch

compressor.optimize(optimizer=torch.optim.Adam, lr=1.0E-7, epochs=1)
compressor.test()

# %%
import torch

compressor.optimize(optimizer=torch.optim.Adam, lr=1.0E-5, comparison_function='RSCC', epochs=3)
compressor.test()
# Out:
# Итерация: 2 из 2 | Прошло времени: 9s476ms из 9s476ms, Осталось: 0us0ns | Средний лосс: 5.12·10⁻¹
# Итерация: 11 из 11 | Прошло времени: 1m4s из 1m4s, Осталось: 0us0ns | Текущий лосс: 6.01·10⁻¹  | Средний лосс за 10 операций: 6.1·10⁻¹
# Итерация: 2 из 2 | Прошло времени: 9s847ms из 9s847ms, Осталось: 0us0ns | Средний лосс: 5.34·10⁻¹
# Итерация: 11 из 11 | Прошло времени: 1m5s из 1m5s, Осталось: 0us0ns | Текущий лосс: 5.61·10⁻¹  | Средний лосс за 10 операций: 5.16·10⁻¹
# Итерация: 2 из 2 | Прошло времени: 9s786ms из 9s786ms, Осталось: 0us0ns | Средний лосс: 5.19·10⁻¹
# Итерация: 11 из 11 | Прошло времени: 1m6s из 1m6s, Осталось: 0us0ns | Текущий лосс: 4.6·10⁻¹  | Средний лосс за 10 операций: 5.01·10⁻¹
# Итерация: 2 из 2 | Прошло времени: 9s941ms из 9s941ms, Осталось: 0us0ns | Средний лосс: 5.15·10⁻¹
